# %% [markdown]
# # ChainerMN with Infiniband サンプルコード

# %% [markdown]
# ## Azure ML service Python SDK 確認

# %%
import azureml.core

print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.0.15

# %% [markdown]
# ## ワークスペースへの接続
# Azure Machine Learning service の [ワークスペース](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#workspace) に接続します。Azureに対する認証が必要になります。

# %%
from azureml.core.workspace import Workspace

ws = Workspace.get(name='azureml', 
                      subscription_id='9c0f91b8-eb2f-484c-979c-15848c098a6b', 
                      resource_group='dllab'
                   )
#ws = Workspace.from_config()
print('Workspace name: ' + ws.name, 
      'Azure region: ' + ws.location, 
      'Subscription id: ' + ws.subscription_id, 
      'Resource group: ' + ws.resource_group, sep = '\n')
# Out:
# Workspace name: azureml
# Azure region: eastus
# Subscription id: 9c0f91b8-eb2f-484c-979c-15848c098a6b
# Resource group: dllab

# %% [markdown]
# ## 計算環境 Machine Learning Compute (旧Batch AI) の新規作成 or 既存環境設定
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) to execute your training script on. In this tutorial, you create an [Azure Batch AI](https://docs.microsoft.com/azure/batch-ai/overview) cluster as your training compute resource. This code creates a cluster for you if it does not already exist in your workspace.
#
# **Creation of the cluster takes approximately 5 minutes.** If the cluster is already in your workspace this code will skip the cluster creation process.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

batchai_cluster_name = "gpu-ib"
vm_size = "Standard_NC24rs_v3"

try:
    # Check for existing cluster
    compute_target = ComputeTarget(ws,batchai_cluster_name)
    print('Found existing compute target ' + batchai_cluster_name)
except:
    # Else, create new one
    print('Creating a new compute target...')
    provisioning_config = AmlCompute.provisioning_configuration(vm_size = vm_size,
                                                                    vm_priority = "lowpriority",
                                                                    min_nodes = 0, 
                                                                    max_nodes = 2)
    compute_target = ComputeTarget.create(ws, batchai_cluster_name, provisioning_config)
    # can poll for a minimum number of nodes and for a specific timeout. 
    # if no min node count is provided it will use the scale settings for the cluster
    compute_target.wait_for_completion(show_output=True, min_node_count=None, timeout_in_minutes=20)
# Out:
# Creating a new compute target...
# Creating
# Succeeded
# AmlCompute wait for completion finished
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## リモート環境でのモデル開発
# Now that we have the cluster ready to go, let's run our distributed training job.

# %% [markdown]
# ### プロジェクトフォルダの作成
# Create a directory that will contain all the necessary code from your local machine that you will need access to on the remote resource. This includes the training script and any additional files your training script depends on.

# %%
import os

project_folder = './script/chainer'
os.makedirs(project_folder, exist_ok=True)

# %%
# %%writefile {project_folder}/chainer_mnist.py

from __future__ import print_function

import argparse

import chainer
import chainer.functions as F
import chainer.links as L
from chainer import training
from chainer.training import extensions

import chainermn


class MLP(chainer.Chain):

    def __init__(self, n_units, n_out):
        super(MLP, self).__init__(
            # the size of the inputs to each layer will be inferred
            l1=L.Linear(784, n_units),  # n_in -> n_units
            l2=L.Linear(n_units, n_units),  # n_units -> n_units
            l3=L.Linear(n_units, n_out),  # n_units -> n_out
        )

    def __call__(self, x):
        h1 = F.relu(self.l1(x))
        h2 = F.relu(self.l2(h1))
        return self.l3(h2)


def main():
    parser = argparse.ArgumentParser(description='ChainerMN example: MNIST')
    parser.add_argument('--batchsize', '-b', type=int, default=100,
                        help='Number of images in each mini-batch')
    parser.add_argument('--communicator', type=str,
                        default='hierarchical', help='Type of communicator')
    parser.add_argument('--epoch', '-e', type=int, default=20,
                        help='Number of sweeps over the dataset to train')
    parser.add_argument('--gpu', '-g', action='store_true',
                        help='Use GPU')
    parser.add_argument('--out', '-o', default='result',
                        help='Directory to output the result')
    parser.add_argument('--resume', '-r', default='',
                        help='Resume the training from snapshot')
    parser.add_argument('--unit', '-u', type=int, default=1000,
                        help='Number of units')
    args = parser.parse_args()

    # Prepare ChainerMN communicator.

    if args.gpu:
        if args.communicator == 'naive':
            print("Error: 'naive' communicator does not support GPU.\n")
            exit(-1)
        comm = chainermn.create_communicator(args.communicator)
        device = comm.intra_rank
    else:
        if args.communicator != 'naive':
            print('Warning: using naive communicator '
                  'because only naive supports CPU-only execution')
        comm = chainermn.create_communicator('naive')
        device = -1

    if comm.rank == 0:
        print('==========================================')
        print('Num process (COMM_WORLD): {}'.format(comm.size))
        if args.gpu:
            print('Using GPUs')
        print('Using {} communicator'.format(args.communicator))
        print('Num unit: {}'.format(args.unit))
        print('Num Minibatch-size: {}'.format(args.batchsize))
        print('Num epoch: {}'.format(args.epoch))
        print('==========================================')

    model = L.Classifier(MLP(args.unit, 10))
    if device >= 0:
        chainer.cuda.get_device_from_id(device).use()
        model.to_gpu()

    # Create a multi node optimizer from a standard Chainer optimizer.
    optimizer = chainermn.create_multi_node_optimizer(
        chainer.optimizers.Adam(), comm)
    optimizer.setup(model)

    # Split and distribute the dataset. Only worker 0 loads the whole dataset.
    # Datasets of worker 0 are evenly split and distributed to all workers.
    if comm.rank == 0:
        train, test = chainer.datasets.get_mnist()
    else:
        train, test = None, None
    train = chainermn.scatter_dataset(train, comm, shuffle=True)
    test = chainermn.scatter_dataset(test, comm, shuffle=True)

    train_iter = chainer.iterators.SerialIterator(train, args.batchsize)
    test_iter = chainer.iterators.SerialIterator(test, args.batchsize,
                                                 repeat=False, shuffle=False)

    updater = training.StandardUpdater(train_iter, optimizer, device=device)
    trainer = training.Trainer(updater, (args.epoch, 'epoch'), out=args.out)

    # Create a multi node evaluator from a standard Chainer evaluator.
    evaluator = extensions.Evaluator(test_iter, model, device=device)
    evaluator = chainermn.create_multi_node_evaluator(evaluator, comm)
    trainer.extend(evaluator)

    # Some display and output extensions are necessary only for one worker.
    # (Otherwise, there would just be repeated outputs.)
    if comm.rank == 0:
        trainer.extend(extensions.dump_graph('main/loss'))
        trainer.extend(extensions.LogReport())
        trainer.extend(extensions.PrintReport(
            ['epoch', 'main/loss', 'validation/main/loss',
             'main/accuracy', 'validation/main/accuracy', 'elapsed_time']))
        trainer.extend(extensions.ProgressBar())

    if args.resume:
        chainer.serializers.load_npz(args.resume, trainer)

    trainer.run()


if __name__ == '__main__':
    main()
# Out:
# Overwriting ./script/chainer/chainer_mnist.py

# %% [markdown]
# ### Experiment "実験" の作成
# [Experiment"実験"](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#experiment) を作成し、Chainerによるモデル学習をトラックします。

# %%
from azureml.core import Experiment

experiment_name = 'chainermn-remote-IB'
experiment = Experiment(ws, name=experiment_name)

# %%
script_params = {
    '-g': '',
    '--communicator': 'non_cuda_aware',
    '-o': './outputs'
}

# %%
from azureml.train.dnn import *

estimator = Chainer(source_directory=project_folder,
                      compute_target=compute_target,
                      entry_script='chainer_mnist.py',
                      script_params=script_params,
                      node_count=2,
                      process_count_per_node=2,
                      distributed_backend='mpi',     
                      pip_packages=['mpi4py'],
                      use_gpu=True)

estimator.run_config.environment.environment_variables['NCCL_SOCKET_IFNAME'] = 'eth0'
estimator.run_config.environment.environment_variables['NCCL_IB_DISABLE'] = '1'

# %% [markdown]
# ### ジョブの実行
# Run your experiment by submitting your estimator object. Note that this call is asynchronous.

# %%
run = experiment.submit(estimator)
print(run)
# Out:
# Run(Experiment: chainermn-remote-IB,
# Id: chainermn-remote-IB_1550803055_be026c66,
# Type: azureml.scriptrun,
# Status: Starting)

# %% [markdown]
# ### run のモニタリング
# You can monitor the progress of the run with a Jupyter widget. Like the run submission, the widget is asynchronous and provides live updates every 10-15 seconds until the job completes.

# %%
from azureml.widgets import RunDetails
RunDetails(run).show()

# %% [markdown]
# Alternatively, you can block until the script has completed training before running more code.

# %%
run.wait_for_completion(show_output=True) # this provides a verbose log
# Out:
# RunId: chainermn-remote-IB_1550803055_be026c66
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
# 2019/02/22 02:37:48 Using acb_vol_a57b654c-9d86-4e8a-bddc-a54703290799 as the home volume
# 2019/02/22 02:37:48 Creating Docker network: acb_default_network, driver: 'bridge'
# 2019/02/22 02:37:48 Successfully set up Docker network: acb_default_network
# 2019/02/22 02:37:48 Setting up Docker configuration...
# 2019/02/22 02:37:49 Successfully set up Docker configuration
# 2019/02/22 02:37:49 Logging in to registry: azureml1139988058.azurecr.io
# 2019/02/22 02:37:50 Successfully logged into azureml1139988058.azurecr.io
# 2019/02/22 02:37:50 Executing step ID: acb_step_0. Working directory: '', Network: 'acb_default_network'
# 2019/02/22 02:37:50 Obtaining source code and scanning for dependencies...
# 2019/02/22 02:37:51 Successfully obtained source code and scanned for dependencies
# 2019/02/22 02:37:51 Launching container with name: acb_step_0
# Sending build context to Docker daemon  40.96kB
#
# Step 1/13 : FROM mcr.microsoft.com/azureml/base-gpu:0.2.1
# 0.2.1: Pulling from azureml/base-gpu
# 7b722c1070cd: Already exists
# 5fbf74db61f1: Already exists
# ed41cb72e5c9: Already exists
# 7ea47a67709e: Already exists
# e986a5da9812: Already exists
# fcf92330fc84: Already exists
# 93f701a1b3a0: Already exists
# 52ab5449a7fb: Already exists
# ad2cbdb1079e: Already exists
# df677fc43fdf: Already exists
# 220ea4374d17: Pulling fs layer
# 220ea4374d17: Verifying Checksum
# 220ea4374d17: Download complete
# 220ea4374d17: Pull complete
# Digest: sha256:eb26cf5e4a6852a3b9029299ee17424b31f458b293066c11824135530617a073
# Status: Downloaded newer image for mcr.microsoft.com/azureml/base-gpu:0.2.1
#  ---> b1d15c3ed71e
# Step 2/13 : USER root
#  ---> Running in 79afc76eea9f
# Removing intermediate container 79afc76eea9f
#  ---> aa4106eb1a4f
# Step 3/13 : RUN mkdir -p $HOME/.cache
#  ---> Running in 64d51b091ce6
# Removing intermediate container 64d51b091ce6
#  ---> 42f0081942d9
# Step 4/13 : WORKDIR /
#  ---> Running in f8ec366bff12
# Removing intermediate container f8ec366bff12
#  ---> 74907b8e7dea
# Step 5/13 : COPY azureml-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> ef105fbb0101
# Step 6/13 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.0; then conda install conda==4.4.11; fi
#  ---> Running in 8c24cf20e2e4
# Removing intermediate container 8c24cf20e2e4
#  ---> 1ea2f41c46a2
# Step 7/13 : COPY azureml-setup/mutated_conda_dependencies.yml azureml-setup/mutated_conda_dependencies.yml
#  ---> 2d414e78f262
# Step 8/13 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_989f56657a2ad33ae08d5c2ac888b63c -f azureml-setup/mutated_conda_dependencies.yml && ldconfig
#  ---> Running in db84005dcd29
# Solving environment: ...working... done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.6.4
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# pip-19.0.1           | 1.8 MB    |            |   0%
# pip-19.0.1           | 1.8 MB    | #######7   |  78%
# pip-19.0.1           | 1.8 MB    | #########2 |  93%
# pip-19.0.1           | 1.8 MB    | ########## | 100%
#
# libstdcxx-ng-8.2.0   | 2.9 MB    |            |   0%
# libstdcxx-ng-8.2.0   | 2.9 MB    | #######8   |  79%
# libstdcxx-ng-8.2.0   | 2.9 MB    | ########## | 100%
#
# libgcc-ng-8.2.0      | 7.6 MB    |            |   0%
# libgcc-ng-8.2.0      | 7.6 MB    | ######8    |  69%
# libgcc-ng-8.2.0      | 7.6 MB    | ########9  |  90%
# libgcc-ng-8.2.0      | 7.6 MB    | ########## | 100%
#
# readline-7.0         | 1.1 MB    |            |   0%
# readline-7.0         | 1.1 MB    | ########3  |  83%
# readline-7.0         | 1.1 MB    | ########## | 100%
#
# openssl-1.0.2p       | 3.5 MB    |            |   0%
# openssl-1.0.2p       | 3.5 MB    | #######5   |  76%
# openssl-1.0.2p       | 3.5 MB    | #########1 |  92%
# openssl-1.0.2p       | 3.5 MB    | ########## | 100%
#
# ca-certificates-2019 | 126 KB    |            |   0%
# ca-certificates-2019 | 126 KB    | ########## | 100%
#
# tk-8.6.8             | 3.1 MB    |            |   0%
# tk-8.6.8             | 3.1 MB    | #######6   |  77%
# tk-8.6.8             | 3.1 MB    | #########  |  91%
# tk-8.6.8             | 3.1 MB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | #4         |  14%
# python-3.6.2         | 27.0 MB   | ###9       |  40%
# python-3.6.2         | 27.0 MB   | ######6    |  67%
# python-3.6.2         | 27.0 MB   | ########2  |  82%
# python-3.6.2         | 27.0 MB   | #########3 |  93%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | #######9   |  80%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# ncurses-6.0          | 920 KB    |            |   0%
# ncurses-6.0          | 920 KB    | #######9   |  79%
# ncurses-6.0          | 920 KB    | #########2 |  92%
# ncurses-6.0          | 920 KB    | ########## | 100%
#
# wheel-0.32.3         | 35 KB     |            |   0%
# wheel-0.32.3         | 35 KB     | ########## | 100%
#
# setuptools-40.8.0    | 647 KB    |            |   0%
# setuptools-40.8.0    | 647 KB    | ########9  |  89%
# setuptools-40.8.0    | 647 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# certifi-2018.11.29   | 146 KB    |            |   0%
# certifi-2018.11.29   | 146 KB    | ########## | 100%
#
# xz-5.2.4             | 366 KB    |            |   0%
# xz-5.2.4             | 366 KB    | #########6 |  97%
# xz-5.2.4             | 366 KB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# libffi-3.2.1         | 43 KB     |            |   0%
# libffi-3.2.1         | 43 KB     | ########## | 100%
# Downloading and Extracting Packages
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting azureml-defaults (from -r /azureml-setup/condaenv.cgq50_xe.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/5e/c9/7de72eb081d96a19bded2cb7528939c9c516f21303b844cd6364a7ca8bf5/azureml_defaults-1.0.15-py2.py3-none-any.whl
# Collecting chainer==5.1.0 (from -r /azureml-setup/condaenv.cgq50_xe.requirements.txt (line 2))
#   Downloading https://files.pythonhosted.org/packages/71/17/e7e3b6f0cd58256085fda9e34623d0de2f888d20dd080ea1c74e8e6c1748/chainer-5.1.0.tar.gz (513kB)
# Collecting cupy-cuda90 (from -r /azureml-setup/condaenv.cgq50_xe.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/2f/f1/06aef468524caa0976748eaabe763ee5aca2e0393d3961438a1eddfcf3b6/cupy_cuda90-5.2.0-cp36-cp36m-manylinux1_x86_64.whl (266.3MB)
# Collecting mpi4py (from -r /azureml-setup/condaenv.cgq50_xe.requirements.txt (line 4))
#   Downloading https://files.pythonhosted.org/packages/55/a2/c827b196070e161357b49287fa46d69f25641930fd5f854722319d431843/mpi4py-3.0.1.tar.gz (1.4MB)
# Collecting applicationinsights>=0.11.7 (from azureml-defaults->-r /azureml-setup/condaenv.cgq50_xe.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/e3/c8/7848a0dd85158930b859eb8be1e38fc76a91f0a040d491723ebb356d7358/applicationinsights-0.11.7-py2.py3-none-any.whl (56kB)
# Collecting azureml-core==1.0.15.* (from azureml-defaults->-r /azureml-setup/condaenv.cgq50_xe.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a9/a6/dd85766160ec29c31200c15b88756fe4fceb8681396e72b2afa32cda712e/azureml_core-1.0.15-py2.py3-none-any.whl (710kB)
# Collecting filelock (from chainer==5.1.0->-r /azureml-setup/condaenv.cgq50_xe.requirements.txt (line 2))
#   Downloading https://files.pythonhosted.org/packages/d7/ca/3c74396a9ed8a4cfab5459800edeef9a1269591cb21f5a49bd71a49c5fa2/filelock-3.0.10-py3-none-any.whl
# Collecting numpy>=1.9.0 (from chainer==5.1.0->-r /azureml-setup/condaenv.cgq50_xe.requirements.txt (line 2))
#   Downloading https://files.pythonhosted.org/packages/f5/bf/4981bcbee43934f0adb8f764a1e70ab0ee5a448f6505bd04a87a2fda2a8b/numpy-1.16.1-cp36-cp36m-manylinux1_x86_64.whl (17.3MB)
# Collecting protobuf>=3.0.0 (from chainer==5.1.0->-r /azureml-setup/condaenv.cgq50_xe.requirements.txt (line 2))
#   Downloading https://files.pythonhosted.org/packages
from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.15.*->azureml-defaults->-r /azureml-setup/condaenv.cgq50_xe.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/ea/cd/35485615f45f30a510576f1a56d1e0a7ad7bd8ab5ed7cdc600ef7cd06222/asn1crypto-0.24.0-py2.py3-none-any.whl (101kB)
# Collecting websocket-client>=0.32.0 (from docker->azureml-core==1.0.15.*->azureml-defaults->-r /azureml-setup/condaenv.cgq50_xe.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/26/2d/f749a5c82f6192d77ed061a38e02001afcba55fe8477336d26a950ab17ce/websocket_client-0.54.0-py2.py3-none-any.whl (200kB)
# Collecting docker-pycreds>=0.4.0 (from docker->azureml-core==1.0.15.*->azureml-defaults->-r /azureml-setup/condaenv.cgq50_xe.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/f5/e8/f6bd1eee09314e7e6dee49cbe2c5e22314ccdb38db16c9fc72d2fa80d054/docker_pycreds-0.4.0-py2.py3-none-any.whl
# Collecting pyasn1>=0.1.1 (from ndg-httpsclient->azureml-core==1.0.15.*->azureml-defaults->-r /azureml-setup/condaenv.cgq50_xe.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/7b/7c/c9386b82a25115cccf1903441bba3cbadcfae7b678a20167347fa8ded34c/pyasn1-0.4.5-py2.py3-none-any.whl (73kB)
# Collecting azure-nspkg>=2.0.0 (from azure-storage-nspkg>=3.0.0->azureml-core==1.0.15.*->azureml-defaults->-r /azureml-setup/condaenv.cgq50_xe.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/c4/0c/c562be95a9a2ed52454f598571cf300b1114d0db2aa27f5b8ed3bb9cd0c0/azure_nspkg-3.0.2-py3-none-any.whl
# Collecting backports.weakref (from backports.tempfile->azureml-core==1.0.15.*->azureml-defaults->-r /azureml-setup/condaenv.cgq50_xe.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/88/ec/f598b633c3d5ffe267aaada57d961c94fdfa183c5c3ebda2b6d151943db6/backports.weakref-1.0.post1-py2.py3-none-any.whl
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_989f56657a2ad33ae08d5c2ac888b63c/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core==1.0.15.*->azureml-defaults->-r /azureml-setup/condaenv.cgq50_xe.requirements.txt (line 1)) (2018.11.29)
# Collecting chardet<3.1.0,>=3.0.2 (from requests>=2.19.1->azureml-core==1.0.15.*->azureml-defaults->-r /azureml-setup/condaenv.cgq50_xe.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
# Collecting idna<2.9,>=2.5 (from requests>=2.19.1->azureml-core==1.0.15.*->azureml-defaults->-r /azureml-setup/condaenv.cgq50_xe.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl (58kB)
# Collecting requests-oauthlib>=0.5.0 (from msrest>=0.5.1->azureml-core==1.0.15.*->azureml-defaults->-r /azureml-setup/condaenv.cgq50_xe.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/c2/e2/9fd03d55ffb70fe51f587f20bcf407a6927eb121de86928b34d162f0b1ac/requests_oauthlib-1.2.0-py2.py3-none-any.whl
# Collecting isodate>=0.6.0 (from msrest>=0.5.1->azureml-core==1.0.15.*->azureml-defaults->-r /azureml-setup/condaenv.cgq50_xe.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
# Collecting pynacl>=1.0.1 (from paramiko>=2.0.8->azureml-core==1.0.15.*->azureml-defaults->-r /azureml-setup/condaenv.cgq50_xe.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/27/15/2cd0a203f318c2240b42cd9dd13c931ddd61067809fee3479f44f086103e/PyNaCl-1.3.0-cp34-abi3-manylinux1_x86_64.whl (759kB)
# Collecting bcrypt>=3.1.3 (from paramiko>=2.0.8->azureml-core==1.0.15.*->azureml-defaults->-r /azureml-setup/condaenv.cgq50_xe.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/d0/79/79a4d167a31cc206117d9b396926615fa9c1fdbd52017bcced80937ac501/bcrypt-3.1.6-cp34-abi3-manylinux1_x86_64.whl (55kB)
# Collecting pycparser (from cffi!=1.11.3,>=1.8->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.15.*->azureml-defaults->-r /azureml-setup/condaenv.cgq50_xe.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/68/9e/49196946aee219aead1290e00d1e7fdeab8567783e83e1b9ab5585e6206a/pycparser-2.19.tar.gz (158kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core==1.0.15.*->azureml-defaults->-r /azureml-setup/condaenv.cgq50_xe.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/16/95/699466b05b72b94a41f662dc9edf87fda4289e3602ecd42d27fcaddf7b56/oauthlib-3.0.1-py2.py3-none-any.whl (142kB)
# Building wheels for collected packages: chainer, mpi4py, pathspec, pyyaml, SecretStorage, pycparser
#   Building wheel for chainer (setup.py): started
#   Building wheel for chainer (setup.py): finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/91/82/5d/4ef2ad99aa90614010eced537d2074b31c5c15f75cb278d272
#   Building wheel for mpi4py (setup.py): started
#   Building wheel for mpi4py (setup.py): finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/58/43/98/b31d9ba388287a8523b04034f4306d83bb2be0492e2514f0be
#   Building wheel for pathspec (setup.py): started
#   Building wheel for pathspec (setup.py): finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/45/cb/7e/ce6e6062c69446e39e328170524ca8213498bc66a74c6a210b
#   Building wheel for pyyaml (setup.py): started
#   Building wheel for pyyaml (setup.py): finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/ad/da/0c/74eb680767247273e2cf2723482cb9c924fe70af57c334513f
#   Building wheel for SecretStorage (setup.py): started
#   Building wheel for SecretStorage (setup.py): finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/4e/5b/1b/be8c8a830a0243af85b2946a0aece2c6743d7f7f946977ed67
#   Building wheel for pycparser (setup.py): started
#   Building wheel for pycparser (setup.py): finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/f2/9a/90/de94f8556265ddc9d9c8b271b0f63e57b26fb1d67a45564511
# Successfully built chainer mpi4py pathspec pyyaml SecretStorage pycparser
# Installing collected packages: applicationinsights, azure-nspkg, azure-mgmt-nspkg, six, python-dateutil, PyJWT, pycparser, cffi, asn1crypto, cryptography, chardet, urllib3, idna, requests, adal, oauthlib, requests-oauthlib, isodate, msrest, msrestazure, azure-common, azure-mgmt-keyvault, ruamel.yaml, azure-mgmt-authorization, websocket-client, docker-pycreds, docker, pathspec, pyopenssl, pyasn1, ndg-httpsclient, pyyaml, azure-storage-nspkg, colorama, backports.weakref, backports.tempfile, pytz, jmespath, jsonpickle, azure-mgmt-resource, azure-storage-common, azure-storage-blob, azure-mgmt-storage, azure-graphrbac, contextlib2, pynacl, bcrypt, paramiko, azure-mgmt-containerregistry, SecretStorage, azureml-core, azureml-defaults, filelock, numpy, protobuf, chainer, fastrlock, cupy-cuda90, mpi4py
# Successfully installed PyJWT-1.7.1 SecretStorage-2.3.1 adal-1.2.1 applicationinsights-0.11.7 asn1crypto-0.24.0 azure-common-1.1.18 azure-graphrbac-0.53.0 azure-mgmt-authorization-0.51.1 azure-mgmt-containerregistry-2.7.0 azure-mgmt-keyvault-1.1.0 azure-mgmt-nspkg-3.0.2 azure-mgmt-resource-2.1.0 azure-mgmt-storage-3.1.1 azure-nspkg-3.0.2 azure-storage-blob-1.5.0 azure-storage-common-1.4.0 azure-storage-nspkg-3.1.0 azureml-core-1.0.15 azureml-defaults-1.0.15 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-3.1.6 cffi-1.12.1 chainer-5.1.0 chardet-3.0.4 colorama-0.4.1 contextlib2-0.5.5 cryptography-2.5 cupy-cuda90-5.2.0 docker-3.7.0 docker-pycreds-0.4.0 fastrlock-0.4 filelock-3.0.10 idna-2.8 isodate-0.6.0 jmespath-0.9.3 jsonpickle-1.1 mpi4py-3.0.1 msrest-0.6.4 msrestazure-0.6.0 ndg-httpsclient-0.5.1 numpy-1.16.1 oauthlib-3.0.1 paramiko-2.4.2 pathspec-0.5.9 protobuf-3.6.1 pyasn1-0.4.5 pycparser-2.19 pynacl-1.3.0 pyopenssl-19.0.0 python-dateutil-2.8.0 pytz-2018.9 pyyaml-3.13 requests-2.21.0 requests-oauthlib-1.2.0 ruamel.yaml-0.15.51 six-1.12.0 urllib3-1.23 websocket-client-0.54.0
#
# #
# # To activate this environment, use:
# # > source activate /azureml-envs/azureml_989f56657a2ad33ae08d5c2ac888b63c
# #
# # To deactivate an active environment, use:
# # > source deactivate
# #
#
# Removing intermediate container db84005dcd29
#  ---> 065ea95ae54a
# Step 9/13 : ENV PATH /azureml-envs/azureml_989f56657a2ad33ae08d5c2ac888b63c/bin:$PATH
#  ---> Running in 419ba72c0b32
# Removing intermediate container 419ba72c0b32
#  ---> 617c3fcaae5a
# Step 10/13 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_989f56657a2ad33ae08d5c2ac888b63c/lib:$LD_LIBRARY_PATH
#  ---> Running in 69e2d3522a53
# Removing intermediate container 69e2d3522a53
#  ---> 7aecd67b4ef7
# Step 11/13 : COPY azureml-setup/spark_cache.py azureml-setup/log4j.properties /azureml-setup/
#  ---> 9f4ca4b78dd0
# Step 12/13 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit "--repositories" "https://mmlspark.azureedge.net/maven" "--packages" "com.microsoft.ml.spark:mmlspark_2.11:0.12" /azureml-setup/spark_cache.py'; fi
#  ---> Running in 3cf7ba3e59d6
# Removing intermediate container 3cf7ba3e59d6
#  ---> 51d2720b2ef1
# Step 13/13 : CMD ["bash"]
#  ---> Running in 2b3e6e3ac807
# Removing intermediate container 2b3e6e3ac807
#  ---> a1df91ffea03
# Successfully built a1df91ffea03
# Successfully tagged azureml1139988058.azurecr.io/azureml/azureml_462b14625bd5f54f008396ba9f1c7db3:latest
# 2019/02/22 02:41:09 Successfully executed container: acb_step_0
# 2019/02/22 02:41:09 Executing step ID: acb_step_1. Working directory: '', Network: 'acb_default_network'
# 2019/02/22 02:41:09 Pushing image: azureml1139988058.azurecr.io/azureml/azureml_462b14625bd5f54f008396ba9f1c7db3:latest, attempt 1
# The push refers to repository [azureml1139988058.azurecr.io/azureml/azureml_462b14625bd5f54f008396ba9f1c7db3]
# 4dbf2ca57df8: Preparing
# ddc3b2b75d3a: Preparing
# 327b360bc15c: Preparing
# 7d0f4f18020a: Preparing
# aab3c1b7821d: Preparing
# c5088e4dcdf9: Preparing
# 1af194b284e7: Preparing
# a47a9623d406: Preparing
# 51713b8e3669: Preparing
# bf847be1c797: Preparing
# 553141bf0a37: Preparing
# 5fb2a9818ab4: Preparing
# 68dda0c9a8cd: Preparing
# f67191ae09b8: Preparing
# b2fd8b4c3da7: Preparing
# 0de2edf7bff4: Preparing
# c5088e4dcdf9: Waiting
# 1af194b284e7: Waiting
# a47a9623d406: Waiting
# 51713b8e3669: Waiting
# bf847be1c797: Waiting
# 553141bf0a37: Waiting
# 5fb2a9818ab4: Waiting
# 68dda0c9a8cd: Waiting
# f67191ae09b8: Waiting
# b2fd8b4c3da7: Waiting
# 0de2edf7bff4: Waiting
# 4dbf2ca57df8: Pushed
# 7d0f4f18020a: Pushed
# aab3c1b7821d: Pushed
# 327b360bc15c: Pushed
# a47a9623d406: Pushed
# 51713b8e3669: Pushed
# 1af194b284e7: Pushed
# 5fb2a9818ab4: Pushed
# 68dda0c9a8cd: Pushed
# f67191ae09b8: Pushed
# b2fd8b4c3da7: Pushed
# bf847be1c797: Pushed
# 553141bf0a37: Pushed
# 0de2edf7bff4: Pushed
# c5088e4dcdf9: Pushed
# ddc3b2b75d3a: Pushed
# latest: digest: sha256:01bae0b2de9a7d14c05c255eb0da39a62f867ee11d656762ff81d6529d5d1c5d size: 3679
# 2019/02/22 02:44:49 Successfully pushed image: azureml1139988058.azurecr.io/azureml/azureml_462b14625bd5f54f008396ba9f1c7db3:latest
# 2019/02/22 02:44:49 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 198.758455)
# 2019/02/22 02:44:49 Populating digests for step ID: acb_step_0...
# 2019/02/22 02:44:51 Successfully populated digests for step ID: acb_step_0
# 2019/02/22 02:44:51 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 220.524285)
# 2019/02/22 02:44:51 The following dependencies were found:
# 2019/02/22 02:44:51
# - image:
#     registry: azureml1139988058.azurecr.io
#     repository: azureml/azureml_462b14625bd5f54f008396ba9f1c7db3
#     tag: latest
#     digest: sha256:01bae0b2de9a7d14c05c255eb0da39a62f867ee11d656762ff81d6529d5d1c5d
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/base-gpu
#     tag: 0.2.1
#     digest: sha256:eb26cf5e4a6852a3b9029299ee17424b31f458b293066c11824135530617a073
#   git: {}
#
#
# Run ID: ca5 was successful after 7m11s
